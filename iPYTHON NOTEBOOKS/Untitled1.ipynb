# %%
import pandas as pd
import numpy as np
from pandas import *
import os
import psycopg2
import sys
import brewer2mpl
import pylab as pl
import matplotlib as mpl
import matplotlib
import matplotlib.pyplot as plt
import scipy as sc
from scipy import stats
from scipy.stats import norm
from pylab import *
from numpy import float64
from mpltools import style
from mpltools import special
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols
from sklearn import mixture
import random
from sklearn.cluster import KMeans
from matplotlib.ticker import NullFormatter
from sklearn.neighbors.kde import KernelDensity
import mpld3
from mpld3 import plugins, utils
from numpy import loadtxt


style.use('ggplot')

pd.set_option('max_rows',4000)
pd.set_option('max_columns',1000)
pandas.set_option('precision',3)
os.chdir('C:\Users\JP\Desktop\Erry emails')

# %%
f= open("C:\Users\JP\Desktop\Erry emails\part1.txt", "r")
g= open("C:\Users\JP\Desktop\Erry emails\part2.txt", "r")

# %%
lines = f.readlines()
lines2 = g.readlines()

# %%
name_dict = {}
names = 0
for line in lines2:
    if line[:4] == 'From':
        for l in range(len(line)):
            if len(line) == 0:
                pass
            elif line[l] == '[':
                name_dict[names] = line[l+1:-2]
                if name_dict[names][:7] == 'mailto:':
                    name_dict[names] = line[l+8:-2]
                print name_dict[names]
                if name_dict[names][-1] == ']':
                    name_dict[names] = name_dict[names][:-1]
                names += 1
                
# for line in lines2:
#     if line[:4] == 'From':
#         for l in range(len(line)):
#             if line[l] == '[':
#                 name_dict[names] = line[l+1:-2]
#                 if name_dict[names][:7] == 'mailto:':
#                     name_dict[names] = line[l+8:-2]
#                 if name_dict[names][-1] == ']':
#                     name_dict[names] = name_dict[names][:-1]
#                 names += 1
# Out:
# zach@talentresources.com
# needmorehangers@hangershortage.com
# zach@talentresources.com
# stephanie@talentresources.com
# pivotalnyc@gmail.com
# erica@pivotal-pr.com]
# Alana@flywheelsports.com
# jen@pivotal-pr.com]
# zach@talentresources.com
# matt@talentresources.com
# no-reply@flywheelsports.com
# orit@ogroup.net
# pivotalnyc@gmail.com
# Alana@flywheelsports.com]
# jen@pivotal-pr.com]
# beautyinnewyork@gmail.com]
# mheller@talentresources.com]
# sdecastro@joico.com
# Sarah.Gowrie@lls.org
# erica@pivotal-pr.com]
# Sarah.Gowrie@lls.org]
# Sarah.Gowrie@lls.org
# erica@pivotal-pr.com]
# jessica.spring@gmail.com
# mheller@talentresources.com]
# jessica.urcelay@gmail.com
# jessica.urcelay@gmail.com
# lindsay@fingerprintcom.net]
# lchan@fullpic.com]
# haro@email.helpareporter.com
# elyse.oleksak@bantambagels.com
# pivotalnyc@gmail.com
# elyse.oleksak@bantambagels.com
# caroline@calvinrucker.com
# cnelsen@fullpic.com
# cnelsen@fullpic.com
# cnelsen@fullpic.com
# jessica.spring@gmail.com
# ...

# %%
names = DataFrame.from_dict(name_dict, orient = 'index')
names.names = 'E-Mail Address'
print names.head()
# Out:
#                                  0
# 0             no-reply@dropbox.com
# 1       jeremy@talentresources.com
# 2             pivotalnyc@gmail.com
# 3          maria@theteaologist.com
# 4  Suzanne.Marchese@usmagazine.com
#
# [5 rows x 1 columns]
